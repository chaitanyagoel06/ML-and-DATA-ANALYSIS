# %% [markdown]
# # IMPORT FILES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # READ FILE

# %%
df = pd.read_csv('BlackFriday.csv')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %% [markdown]
# # DATA ANALYSIS

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023024        0.018732            0.003687
# Occupation         -0.023024    1.000000        0.024691           -0.008114
# Marital_Status      0.018732    0.024691        1.000000            0.020546
# Product_Category_1  0.003687   -0.008114        0.020546            1.000000
# Product_Category_2  0.001471   -0.000031        0.015116            0.540423
# Product_Category_3  0.004045    0.013452        0.019452            0.229490
# Purchase            0.005389    0.021104        0.000129           -0.314125
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                       0.001471            0.004045  0.005389
# Occupation                   -0.000031            0.013452  0.021104
# Marital_Status                0.015116            0.019452  0.000129
# Product_Category_1            0.540423            0.229490 -0.314125
# ...

# %%
print('Shape: ',df.shape)
# Out:
# Shape:  (537577, 12)

# %%
print('Number of shoppers:',df['User_ID'].nunique())
print('Years in city:',df['Stay_In_Current_City_Years'].unique())
print('Age Groups:',df['Age'].unique())
# Out:
# Number of shoppers: 5891
# Years in city: ['2' '4+' '3' '1' '0']
# Age Groups: ['0-17' '55+' '26-35' '46-50' '51-55' '36-45' '18-25']

# %%
count_m = df[df['Gender']=='M'].count()
print('Number of male clients:',count_m)
count_f = df[df['Gender']=='F'].count()
print('Number of female clients:',count_f)
# Out:
# Number of male clients: User_ID                       405380
# Product_ID                    405380
# Gender                        405380
# Age                           405380
# Occupation                    405380
# City_Category                 405380
# Stay_In_Current_City_Years    405380
# Marital_Status                405380
# Product_Category_1            405380
# Product_Category_2            280741
# Product_Category_3            127346
# Purchase                      405380
# dtype: int64
# Number of female clients: User_ID                       132197
# Product_ID                    132197
# Gender                        132197
# Age                           132197
# Occupation                    132197
# City_Category                 132197
# Stay_In_Current_City_Years    132197
# Marital_Status                132197
# Product_Category_1            132197
# Product_Category_2             89850
# Product_Category_3             36932
# ...

# %% [markdown]
# # DATA VISUALISATION

# %%
#Unique Item Purchases by Gender


plt.pie(df.groupby('Gender')['Product_ID'].nunique(),labels=['Male','Female'],
       shadow=True,autopct='%1.01f%%',colors=['r','y'])
plt.title('Unique Item Purchases by Gender')
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)

# %%
#mean purchase by age group


spent_byage = df.groupby(by='Age').sum()['Purchase']
plt.figure(figsize=(12,6))

sns.barplot(x=spent_byage.index,y=spent_byage.values, palette="Blues_d")
plt.xlabel('Age groups')
plt.ylabel('Mean')
plt.title('Mean Purchases per Age Group')
plt.show()

# %%
#Occupation Distribution


sns.countplot(df['Occupation'])
plt.title('Occupation Distribution')
plt.show()

# %%
#Unique Products by Occupation


prod_by_occ = df.groupby(by='Occupation').nunique()['Product_ID']
sns.barplot(x=prod_by_occ.index,y=prod_by_occ.values)
plt.title('Unique Products by Occupation')
plt.show()

# %%
#Total Money Spent per Occupation


spent_by_occ = df.groupby(by='Occupation').sum()['Purchase']
sns.barplot(x=spent_by_occ.index,y=spent_by_occ.values)
plt.title('Total Money Spent per Occupation')
plt.show()

# %%
#Number of Unique Items per Category


prod_by_cat = df.groupby('Product_Category_1')['Product_ID'].nunique()
sns.barplot(x=prod_by_cat.index,y=prod_by_cat.values, palette="cool")
plt.xlabel('prod_by_cat.index')
plt.ylabel('prod_by_cat.values')
plt.title('Number of Unique Items per Category')
plt.show()

# %%
#Number of Unique Items per Category


prod_by_cat = df.groupby('Product_Category_2')['Product_ID'].nunique()
sns.barplot(x=prod_by_cat.index,y=prod_by_cat.values, palette="winter")
plt.xlabel('prod_by_cat.index')
plt.ylabel('prod_by_cat.values')
plt.title('Number of Unique Items per Category')
plt.show()

# %%
#Number of Unique Items per Category


prod_by_cat = df.groupby('Product_Category_3')['Product_ID'].nunique()
sns.barplot(x=prod_by_cat.index,y=prod_by_cat.values, palette="summer")
plt.xlabel('prod_by_cat.index')
plt.ylabel('prod_by_cat.values')
plt.title('Number of Unique Items per Category')
plt.show()

# %% [markdown]
# # VALUE ASSIGNMENT

# %%
X = df.drop(["Purchase"], axis=1)
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
X = X.apply(LE.fit_transform)

X.Gender = pd.to_numeric(X.Gender)
X.Age = pd.to_numeric(X.Age)
X.Occupation = pd.to_numeric(X.Occupation)
X.City_Category = pd.to_numeric(X.City_Category)
X.Stay_In_Current_City_Years = pd.to_numeric(X.Stay_In_Current_City_Years)
X.Marital_Status = pd.to_numeric(X.Marital_Status)
X.Product_Category_1 = pd.to_numeric(X.Product_Category_1)

# %%
y=df['Purchase']
print(y)
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 4          7969
# 5         15227
# 6         19215
# 7         15854
# 8         15686
# 9          7871
# 10         5254
# 11         3957
# 12         6073
# 13        15665
# 14         5378
# 15         2079
# 16        13055
# 17         8851
# 18        11788
# 19        19614
# 20         8584
# 21         9872
# 22         9743
# 23         5982
# 24        11927
# 25        16662
# 26         5887
# 27         6973
# 28         5391
# 29        16352
#           ...
# 537547    11543
# 537548    20924
# 537549    13082
# 537550    11658
# 537551     6863
# 537552    16415
# 537553    18526
# 537554     7099
# 537555      578
# 537556     2183
# 537557    12724
# 537558     7796
# 537559     7770
# 537560     5940
# 537561     7834
# 537562    11508
# 537563     6074
# 537564     7084
# 537565     7934
# 537566     5350
# 537567     1994
# 537568     5930
# 537569     7042
# 537570    15491
# ...

# %%
X
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0             0         670       0    0          10              0
# 1             0        2374       0    0          10              0
# 2             0         850       0    0          10              0
# 3             0         826       0    0          10              0
# 4             1        2732       1    6          16              2
# 5             2        1829       1    2          15              0
# 6             3        1743       1    4           7              1
# 7             3        3318       1    4           7              1
# 8             3        3596       1    4           7              1
# 9             4        2629       1    2          20              0
# 10            4        2396       1    2          20              0
# 11            4         140       1    2          20              0
# 12            4         307       1    2          20              0
# ...

# %% [markdown]
# # DATA SPLITTING

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
fit1 = lr.fit(X_train,y_train)

# %%
pred=lr.predict(X_test)
print(pred)
# Out:
# [10344.01676432  7170.24550778  9769.22099931 ...  7971.09241633
#  10266.06524385  8953.35473779]

# %%
y_test
# Out:
# 225194    11394
# 297411    12781
# 394066    20068
# 504777    15359
# 347720    12665
# 182738    11730
# 303833    10012
# 101356    10067
# 495441    15702
# 355330    15376
# 58519      8846
# 482700     9856
# 50243      2144
# 238868    15754
# 129350    16613
# 395474     6970
# 330041     8809
# 318545     8893
# 470952    13225
# 411869    11762
# 358977    15200
# 170412     5474
# 257762    11850
# 378095    15280
# 383872     5826
# 353975    12750
# 165843    19122
# 73331      8685
# 435447     9894
# 407442    16882
#           ...
# 416185     6060
# 8800       1895
# 456524     7159
# 199323    19538
# 418984    15386
# 151030     4110
# 187043     5168
# 397849    12511
# 292923     9894
# 39136      6988
# 390838    16724
# 60667      7157
# 372840    18980
# 321856    11877
# 503628     7957
# 59285     12074
# 232409     3049
# 362996     6171
# 71248     16133
# 447643     6877
# 126797    15633
# 257781     9895
# 377948      579
# 318343     6090
# ...

# %% [markdown]
# # ACCURACY

# %%
from sklearn.metrics import r2_score
accu=r2_score(y_test,pred)
print(accu*100,"%")
# Out:
# 12.556884735831208 %

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
fit1 = lr.fit(X_train,y_train)
print("Accuracy Score of Linear regression on train set",fit1.score(X_train,y_train)*100,"%")
# Out:
# Accuracy Score of Linear regression on train set 12.794737279077406 %

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
fit3 = rfr.fit(X_train,y_train)
print("Accuracy Score of Random Forests on train set",fit3.score(X_train,y_train)*100,"%")
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy Score of Random Forests on train set 94.14013869751314 %
